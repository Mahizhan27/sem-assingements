# %% [markdown]
# # web scrapping

# %% [markdown]
# pip install bs4

# %%
from bs4 import BeautifulSoup

# %%
import pandas as pd

# %%
import requests

# %%
url="https://www.jiomart.com/c/fashion/boys/footwear/1470?prod_mart_fashion_products_popularity%5Bpage%5D=2&prod_mart_fashion_products_popularity%5BrefinementList%5D%5Bstyle%5D%5B0%5D=Clogs&prod_mart_fashion_products_popularity%5Brange%5D%5Bavg_selling_price%5D=%3A2066"

# %%
response=requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
Back_code=BeautifulSoup(response.text)

# %%
Back_code
# Out:
# <!DOCTYPE html>
# ...

# %%
name=Back_code.select(".jm-fc-primary-grey-80")

# %%
name
# Out:
# [<div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> BIRDE Stylish Comfortable Regular Wear Green Light Clogs For Kids </div>,
#  <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> SMARTOTS Kids Stylised Comformtable Lightweight CuteNess Typographic Blue Casual Clogs for 15 Months to 3.5 Years Boys/Girls/Toddler/Infant/Babies </div>,
#  <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> SMARTOTS Kids Dailwear Stylish &amp; Trendy Sky Blue Low-top Breathable Slip-Resistant Lightweight EVA Clogs for 1 to 5.5 Years Boys/Girls/Toddler </div>,
#  <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> SMARTOTS Kids Dailywear Stylised Comfortable Lightweight Orange Solid Casual Slippers for 15 Months to 5.5 Years Boys/Girls/Infant/Toddler/Babies </div>,
# ...

# %%
Price= Back_code.select(".jm-heading-xxs")

# %%
Price
# Out:
# [<span class="jm-heading-xxs jm-mb-xxs">₹329.00</span>,
#  <span class="jm-heading-xxs jm-mb-xxs">₹189.00</span>,
#  <span class="jm-heading-xxs jm-mb-xxs">₹189.00</span>,
#  <span class="jm-heading-xxs jm-mb-xxs">₹179.00</span>,
#  <span class="jm-heading-xxs jm-mb-xxs">₹179.00</span>,
#  <span class="jm-heading-xxs jm-mb-xxs">₹419.00</span>,
#  <span class="jm-heading-xxs jm-mb-xxs">₹169.00</span>,
#  <span class="jm-heading-xxs jm-mb-xxs">₹259.00</span>,
#  <span class="jm-heading-xxs jm-mb-xxs">₹419.00</span>,
#  <span class="jm-heading-xxs jm-mb-xxs">₹373.00</span>,
#  <span class="jm-heading-xxs jm-mb-xxs">₹329.00</span>,
#  <span class="jm-heading-xxs jm-mb-xxs">₹449.00</span>]

# %%
offer=Back_code.select(".jm-badge")

# %%
offer
# Out:
# [<span class="jm-badge"> 78% OFF </span>,
#  <span class="jm-badge"> 62% OFF </span>,
#  <span class="jm-badge"> 62% OFF </span>,
#  <span class="jm-badge"> 55% OFF </span>,
#  <span class="jm-badge"> 55% OFF </span>,
#  <span class="jm-badge"> 58% OFF </span>,
#  <span class="jm-badge"> 66% OFF </span>,
#  <span class="jm-badge"> 56% OFF </span>,
#  <span class="jm-badge"> 58% OFF </span>,
#  <span class="jm-badge"> 75% OFF </span>,
#  <span class="jm-badge"> 78% OFF </span>,
#  <span class="jm-badge"> 35% OFF </span>]

# %%
Dress_data=pd.DataFrame(name,columns=["name"])

# %%
Dress_data
# Out:
#                                                  name
# 0    BIRDE Stylish Comfortable Regular Wear Green ...
# 1    SMARTOTS Kids Stylised Comformtable Lightweig...
# 2    SMARTOTS Kids Dailwear Stylish & Trendy Sky B...
# 3    SMARTOTS Kids Dailywear Stylised Comfortable ...
# 4    SMARTOTS Kids Dailywear Stylised Comfortable ...
# 5    School shoes for Children Boys and Girls Form...
# 6    SMARTOTS Newborn Baby Shoes Booties & Mittens...
# 7    Birde Stylish Regular Wear Olive Green Clogs ...
# 8    Adicon School shoes Black boys Formal Black s...
# 9       NEOBABY Red Velcro Sneakers for Boys & Girls
# 10   BIRDE Comfortable Regular Wear Orange:Grey Li...
# 11      KRAKKI Toddlers Teddy Print Extra Soft Clogs

# %%
Dress_data["Price"]=Price

# %%
Dress_data["offer"]=offer

# %%
Dress_data
# Out:
#                                                  name      Price        offer
# 0    BIRDE Stylish Comfortable Regular Wear Green ...  [₹329.00]  [ 78% OFF ]
# 1    SMARTOTS Kids Stylised Comformtable Lightweig...  [₹189.00]  [ 62% OFF ]
# 2    SMARTOTS Kids Dailwear Stylish & Trendy Sky B...  [₹189.00]  [ 62% OFF ]
# 3    SMARTOTS Kids Dailywear Stylised Comfortable ...  [₹179.00]  [ 55% OFF ]
# 4    SMARTOTS Kids Dailywear Stylised Comfortable ...  [₹179.00]  [ 55% OFF ]
# 5    School shoes for Children Boys and Girls Form...  [₹419.00]  [ 58% OFF ]
# 6    SMARTOTS Newborn Baby Shoes Booties & Mittens...  [₹169.00]  [ 66% OFF ]
# 7    Birde Stylish Regular Wear Olive Green Clogs ...  [₹259.00]  [ 56% OFF ]
# 8    Adicon School shoes Black boys Formal Black s...  [₹419.00]  [ 58% OFF ]
# 9       NEOBABY Red Velcro Sneakers for Boys & Girls   [₹373.00]  [ 75% OFF ]
# 10   BIRDE Comfortable Regular Wear Orange:Grey Li...  [₹329.00]  [ 78% OFF ]
# ...

# %%
Dress_data_to.csv("footwears.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2312/3248959385.py in <module>
# ----> 1 Dress_data_to.csv("footwears.csv")
#
# NameError: name 'Dress_data_to' is not defined
